# %%
import nltk, pickle, string
from nltk.corpus import stopwords
import re
import os
from tika import parser
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences


from textblob.classifiers import NaiveBayesClassifier as NBC
from textblob import TextBlob
# Out:
# Using TensorFlow backend.

# %%
def clean_doc(doc):
    """
    Cleaning a document by several methods:
        - Lowercase
        - Removing whitespaces
        - Removing stopwords
        - Removing punctuations
        
    """
    stop_words = set(stopwords.words('english'))
    
    # Lowercase
    doc = doc.lower()
   
    tokens = doc.translate({ord(c):"" for c in "\u200b\uf020\u2028\xa0\uf0e0\uf095\uf041\uf0e1\uf0b7\xad"})
    tokens = tokens.translate({ord(c):" " for c in "[):,·](;•●■♦▪"})
    tokens = tokens.translate({ord(c):"f" for c in "�"})
    
    # Removing multiple whitespaces
    tokens = re.sub(r"\?", " \? ", tokens)
    
    # Split in tokens
    tokens = tokens.split()
    
    # Remove Stopwords
    tokens = [w for w in tokens if not w in stop_words]
    # Remove punctuation
    tokens = [w.translate(str.maketrans('', '', string.punctuation)) for w in tokens]
    
    return ' '.join(tokens)

# %%
def LoadData_tech():
    label_tech=[]
    i=0
    for foldername in os.listdir("/home/shabna/Desktop/example_codes/new_sample/level3/tech"):
        for file in os.listdir("/home/shabna/Desktop/example_codes/new_sample/level3/tech/"+foldername):
    
            try:
                print (i, foldername, file)
                parsedPDF = parser.from_file("/home/shabna/Desktop/example_codes/new_sample/level3/tech/"+foldername+"/"+file)

                resume_contents=clean_doc(parsedPDF['content'])
            #Data = resume_contents.encode('utf-8')    
                label_tech.append((resume_contents,foldername))
            except UnicodeEncodeError:
                print ('Unicode error:', file)
            i=i+1
    #print (label_resume)
    return(label_tech)

# %%
label_tech=LoadData_tech()
# Out:
# 0 content writer BrettJohnsonProfile.pdf
# 1 content writer Maria ChristineJohnsonProfile.pdf
# 2 content writer HelenHarbord FISTCProfile.pdf
# 3 content writer MohanReddy[7_0].doc
# 4 content writer PiyushPranavProfile.pdf
# 5 content writer Content Writer -Interested.docx
# 6 content writer CV_Vibin.docx
# 7 content writer Prem Hans RajSinghProfile.pdf
# 8 content writer AnjuRachelThomas[1_0].docx
# 9 content writer Febajacob[2_0].docx
# 10 content writer ManjunathMProfile.pdf
# 11 content writer PreetiKusnoorProfile.pdf
# 12 content writer NandiniVijayagopal[7_0].docx
# 13 content writer NandlalSharma[5_4].doc
# 14 content writer NityaMarwah[5_0].docx
# 15 content writer AarushiNairProfile.pdf
# 16 content writer AmelAbdul RahmanProfile.pdf
# 17 content writer DheerajKapoor[5_0].pdf
# 18 content writer NatashaMirandaProfile.pdf
# 19 content writer DivyaBhanotProfile.pdf
# 20 content writer RadhikaLingampalliProfile.pdf
# 21 content writer Deepthi.pdf
# 22 content writer AJAYKUMARM[5_2].docx
# 23 content writer ABHIJITHT[2_0].docx
# 24 content writer JinuKurian[6_0].doc
# 25 content writer RashmiMadhusudhanProfile.pdf
# 26 content writer HappyUpadhyayProfile.pdf
# 27 content writer HerbertG[9_0].docx
# 28 content writer Dinesh Kumar Nataraj_Technical_Writer_Technical_Communicator_&_Editor_7years.docx
# 29 content writer LekhaKoshyVaidyan[8_0].doc
# 30 content writer EdBacherProfile.pdf
# 31 content writer MEGHAMARWARIProfile.pdf
# 32 content writer JulieMary GProfile.pdf
# 33 content writer BenjaminMillerProfile.pdf
# 34 content writer AnamikaSharmaProfile.pdf
# 35 content writer BhartiAgrawalProfile.pdf
# 36 content writer NIPUNDEVProfile.pdf
# 37 content writer HariniSeshadriProfile.pdf
# 38 content writer PrateekSharma[6_0].pdf
# 39 content writer PrietyDas (Looking for Job Change)Profile(1).pdf
# 40 content writer KrishnenduBP[2_6].doc
# 41 content writer ParthaBanik[6_0].doc
# 42 content writer GOPUSANKAR[5_11].docx
# 43 content writer KristinBlicharz WitherspoonProfile.pdf
# 44 content writer IrmaCaraballoProfile.pdf
# 45 content writer arpitmandloi[5_3].docx
# 46 content writer arlinjohn[2_7].docx
# 47 content writer DevikaRamesh[2_0].doc
# 48 content writer DhariniSekarProfile.pdf
# 49 content writer KumarSaurabh[9_0].docx
# 50 content writer ElaineAbousalhProfile.pdf
# 51 content writer Priyadarshini[6_0].docx
# 52 content writer ErikLProfile.pdf
# 53 content writer Ashishkumar[5_7].pdf
# 54 content writer Akash KumarJaiswalProfile.pdf
# 55 content writer AananthaGopinathG[5_7].doc
# 56 content writer AneeshKurian[9_0].docx
# 57 content writer HarshaKulkarniProfile.pdf
# 58 content writer GeethaAjay[5_4].pdf
# 59 content writer JyothiSrinathProfile.pdf
# 60 content writer PoojaAgarwalProfile.pdf
# 61 content writer BenJohnsonProfile.pdf
# 62 content writer PankajMadanProfile.pdf
# 63 content writer PurushothamanSamudhra RajakumarProfile.pdf
# 64 content writer DackshtaRana[1_0].pdf
# 65 content writer ChitraMurthyProfile.pdf
# 66 content writer RamyaRameshProfile.pdf
# 67 content writer KimNylanderProfile.pdf
# 68 content writer ManasaRajProfile.pdf
# 69 content writer EveMeelanProfile.pdf
# 70 content writer AnkurDeep[5_0].docx
# 71 content writer NairitaGangopadhyay[5_0].docx
# 72 content writer DeepashreeRavindraProfile.pdf
# 73 content writer MichelleCherianProfile.pdf
# 74 content writer KavithaPatchamalaiProfile.pdf
# 75 content writer Liza BarooahGogoiProfile.pdf
# 76 content writer KaranBalwani[5_0].docx
# 77 content writer Nagaraju[7_0].docx
# 78 content writer ArunaZachariahProfile.pdf
# 79 content writer JoelHamillProfile.pdf
# 80 content writer Athirajoy[4_0].docx
# 81 content writer PMDMehetab[8_0].pdf
# 82 content writer JulieDanielProfile.pdf
# 83 content writer ChowdalaVimalaProfile.pdf
# 84 content writer KempanahalliSKantharaju[6_0].doc
# 85 content writer AlexNicolsonProfile.pdf
# 86 content writer AkhilJohn[1_6].doc
# 87 content writer Prabhjotkaur[5_7].docx
# 88 content writer RahulLakshmananProfile.pdf
# 89 content writer Eldhose George[3_10].pdf
# 90 content writer MagarikaVSProfile.pdf
# 91 content writer Dinesh KumarNatrajProfile.pdf
# 92 content writer Anoop[4_0].pdf
# 93 content writer AdarshChandran[6_0].doc
# 94 content writer AnuradhaShetProfile.pdf
# 95 content writer RajaMProfile.pdf
# 96 content writer KevinBlakeProfile.pdf
# 97 content writer ArunkumarBalakrishnanProfile.pdf
# 98 content writer DilipVasudevanProfile.pdf
# 99 content writer ArathiKadam KiranProfile(1).pdf
# 100 content writer Anthony Louis. A_technical Writer _Bangalore _Atlas Systems.doc
# 101 content writer NarendraKumandan[5_1].pdf
# 102 content writer KristinBlicharz WitherspoonProfile(1).pdf
# 103 content writer contentwriter.docx
# 104 content writer KrishnaPrasanna (1).doc
# 105 content writer BalajiDaruvoori[8_0].doc
# 106 content writer GokulaKrishnan.docx
# 107 content writer RamyaDominicProfile.pdf
# 108 content writer PrietyDas (Looking for Job Change)Profile.pdf
# 109 content writer HemaDassProfile.pdf
# 110 content writer Anand Kumar[8_0].doc
# 111 content writer PAYAL[9_0].doc
# 112 content writer Experienced Technical Writer Resume.doc
# 113 content writer JayaaSProfile.pdf
# 114 content writer MadhuriKaranthProfile.pdf
# 115 content writer JyotiTripathiProfile.pdf
# 116 content writer Content Developer
# 117 content writer IyshwaryaSekarProfile.pdf
# 118 content writer RajasekaranB[5_5].docx
# 119 content writer PriyaTripathiProfile.pdf
# 120 content writer BharathiKotlaProfile.pdf
# 121 content writer debojitborah[9_0].docx
# 122 content writer PreranaSolankiProfile.pdf
# 123 content writer LisaJohnsonProfile.pdf
# 124 content writer ChrisFrostProfile.pdf
# 125 content writer LAHEENAVI[1_1].pdf
# 126 content writer AniMolBaby[1_5].doc
# 127 content writer Dineshkumar EJ.doc
# 128 content writer BhavyaValsanProfile.pdf
# 129 content writer ArathiKadam KiranProfile.pdf
# 130 content writer BageshriKachhawaProfile.pdf
# 131 content writer NireshManjunathB[7_0].docx
# 132 content writer Anoop_f.docx
# 133 content writer Kranthi KumarTaduriProfile.pdf
# 134 content writer JadePhillips Joyner, MSProfile.pdf
# 135 content writer JoseGonsalo-ContentWriter-Resume.pdf
# 136 content writer PoojaBahl[5_0].docx
# 137 content writer MohammedZubairAhamedB[7_0].pdf
# 138 content writer Nita Anil -Interested.docx
# 139 content writer DeepaliBhandariProfile.pdf
# 140 content writer MaanasaSuthraveProfile.pdf
# 141 content writer PallaviGururajProfile.pdf
# 142 content writer MuralidharanThangaraj[5_6].docx
# 143 content writer AnanthK.Profile.pdf
# 144 content writer praveendamodaran[7_0].doc
# 145 content writer DivyakaushikProfile.pdf
# 146 content writer AnoopaSebastian[2_0].doc
# 147 content writer dineshkumar[8_0].pdf
# 148 content writer KarthikaSelvamProfile.pdf
# 149 content writer NaveenKumarProfile.pdf
# 150 IT Akshay_Chaudhary_Pune_10.06_yrs.doc
# 151 IT Jose Resume.docx
# 152 IT Dhiraj_Sali_Pune_11.00_yrs.doc
# 153 IT Abhilash Rajan.doc
# 154 IT 83604512_Chennai_12.00_yrs.doc
# 155 IT bejoy ks.pdf
# 156 IT kamal_gangwani_US_3.10_yrs.doc
# 157 IT Deepak_Resume 3i  (1).doc
# 158 IT BabarShahProfile.pdf
# 159 IT Dhirendra_Kumar_Jha_Mumbai_14.03_yrs.doc
# 160 IT dilip_sakwadia_Pune_8.11_yrs.doc
# 161 IT FarshadBAGHERIANProfile.pdf
# 162 IT Muhammad MuneebIqbalProfile.pdf
# 163 IT AKHIL_SABU_Kozhikode___Calicut_4.00_yrs.pdf
# 569 others HEMANT_SETHI_Pune_5.00_yrs.pdf
# 570 others mohd_atif_ahmad_Delhi_1.00_yrs.docx
# 571 others Chennaiah_Pillakadupula_Hyderabad___Secunderabad_5.02_yrs.docx
# 572 others Mariselvam_M_G__Coimbatore_0.04_yrs.docx
# 573 others Anumol_Abraham_Cochin___Kochi___Ernakulam_0.07_yrs.pdf
# 574 others GiuliaSonninoProfile(1).pdf
# 575 others martamunte vidalProfile.pdf
# 576 others Gokulrah__Chennai_1.00_yrs.pdf
# 577 others AndiB.Profile.pdf
# 578 others ClaudiaBrambillaProfile.pdf
# 579 others kamna_pandey_Delhi_0.00_yrs.pdf
# 580 others Alfina_Muthu_Chennai_1.05_yrs.docx
# 581 others Akansha_Singhal_Noida_2.00_yrs.docx
# 582 others 49700435_Bengaluru___Bangalore_16.00_yrs.doc
# 583 others gireeshguptaProfile.pdf
# 584 others Jitendra_Prajapati_Delhi_6.08_yrs.docx
# 585 others EmmaAllsupProfile.pdf
# 586 others Dharamendra_Singh_Delhi_5.02_yrs.doc
# 587 others Amir_Dhuri_Pune_2.08_yrs.docx
# 588 others anilvishnu1(sh)15thJan'16.docx
# 589 others Deepak_Chandel_Delhi_6.00_yrs.doc
# 590 others NURULHUDAProfile.pdf
# 591 others AndieGalloProfile.pdf
# 592 others Animator Fresher Resume.pdf
# 593 others ElisaHartikkaProfile.pdf
# 594 others 3D Animator Resume.doc
# 595 others AngelicaChieffiProfile.pdf
# 596 others AlexeiAltregoProfile(1).pdf
# 597 others Mano_Raj_Chennai_6.00_yrs.pdf
# 598 others AhmedWaheedProfile.pdf
# 599 others Govardhan S.docx

# %%
len(label_tech)
# Out:
# 600

# %%
print(len(label_tech))
# Out:
# 600

# %%
data =[]
data_labels=[]
for i,row in enumerate(label_tech):
    data.append(row[0])
    data_labels.append(row[1])
print(len(data))
print(len(data_labels))
# Out:
# 600
# 600

# %%
print(len(data_labels))
# Out:
# 600

# %%
#labels = [0 for _ in range(len(label_resume))] + [1 for _ in range(len(label_jd))]
#print(labels)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=4, max_df=0.9)

# %%
# Apply model on jdres train data
train_vectors = vectorizer.fit_transform(data)
print(train_vectors)
# Out:
#   (0, 3290)	0.060882531659
#   (0, 2553)	0.0816083278056
#   (0, 4544)	0.130025824652
#   (0, 5027)	0.112958846268
#   (0, 2123)	0.458427538072
#   (0, 1036)	0.282205827529
#   (0, 3442)	0.144274056015
#   (0, 1493)	0.139848205584
#   (0, 3816)	0.103853600453
#   (0, 4455)	0.00986796263957
#   (0, 3647)	0.0294308273541
#   (0, 1109)	0.0346178668176
#   (0, 685)	0.0281448175577
#   (0, 4946)	0.0511330643611
#   (0, 1497)	0.0381986195963
#   (0, 1558)	0.18421341332
#   (0, 2395)	0.0471463835594
#   (0, 1147)	0.0299137895091
#   (0, 4540)	0.105123981287
#   (0, 2671)	0.0633960489104
#   (0, 1317)	0.0806386977995
#   (0, 2045)	0.0212095643146
#   (0, 4541)	0.022573934158
#   (0, 1436)	0.0304300849758
#   (0, 2227)	0.043322092012
#   :	:
#   (599, 4368)	0.0757014495323
#   (599, 1420)	0.0893184756714
#   (599, 1284)	0.0701852554415
#   (599, 1601)	0.114507412986
#   (599, 2452)	0.0640622195626
#   (599, 2031)	0.0747935603569
#   (599, 3019)	0.0695266667423
#   (599, 423)	0.087340679502
#   (599, 4995)	0.0825099626018
#   (599, 1117)	0.125436307346
#   (599, 5038)	0.0799214860664
#   (599, 1664)	0.0595850285487
#   (599, 1787)	0.087340679502
#   (599, 4767)	0.072331815437
#   (599, 3064)	0.102157847406
#   (599, 4097)	0.097210710511
#   (599, 4070)	0.097210710511
#   (599, 821)	0.136564512193
#   (599, 3405)	0.0799214860664
#   (599, 2636)	0.097210710511
#   (599, 144)	0.0839710454067
#   (599, 383)	0.239764458199
#   (599, 2569)	0.148318176763
#   (599, 2496)	0.0776792457017
#   (599, 1118)	0.0825099626018

# %%
X_train, X_test, y_train, y_test = train_test_split(train_vectors, data_labels, test_size=0.2, random_state=42)

# %%
svm_model = svm.SVC(kernel='linear') 
svm_model.fit(X_train, y_train) 
svm_prediction = svm_model.predict(X_train)
import numpy as np
print ('svm:', np.mean(svm_prediction == y_train))

'''for i in range(80):
    print ('>>>>>>>>>>>.',model.predict(train_vectors[i]))'''

    
from sklearn.ensemble import RandomForestClassifier  
RF_model = RandomForestClassifier(max_depth=2, random_state=0)
RF_model.fit(X_train, y_train) 
RF_prediction = RF_model.predict(X_train)
import numpy as np
print ('Random Forest:', np.mean(RF_prediction == y_train))

from sklearn.linear_model import SGDClassifier
SGD_model = SGDClassifier()
SGD_model.fit(X_train, y_train) 
SGD_prediction = SGD_model.predict(X_train)
import numpy as np
print ('SGD:', np.mean(SGD_prediction == y_train))

from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train,y_train)
dtree_predictions = dtree_model.predict(X_train)
print ('DT:', np.mean(dtree_predictions == y_train))


from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train,y_train)
knn_predictions = knn.predict(X_train) 
print ('knn:', np.mean(knn_predictions == y_train))
# Out:
# svm: 1.0
# Random Forest: 0.7875
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGD: 1.0
# DT: 0.64375
# knn: 0.975

# %%
for i in range(800):
    print ('>>>>>>>>>>>.',RF_model.predict(X_train[i]))
    print (y_train[i])
print(len(y_train))
# Out:
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['software']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# others
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['software']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# others
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# IT
# >>>>>>>>>>>. ['others']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-c20e9ae25ba4> in <module>()
#       1 for i in range(800):
# ----> 2     print ('>>>>>>>>>>>.',RF_model.predict(X_train[i]))
#       3     print (y_train[i])
#       4 print(len(y_train))
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     290             # [i, 1:2]
#     291             elif isinstance(col, slice):
# --> 292                 return self._get_row_slice(row, col)
#     293             # [i, [1, 2]]
#     294             elif issequence(col):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_row_slice(self, i, cslice)
#     373
#     374         if i < 0 or i >= self.shape[0]:
# --> 375             raise IndexError('index (%d) out of range' % i)
#     376
#     377         start, stop, stride = cslice.indices(self.shape[1])
#
# IndexError: index (480) out of range

# %%
svm_model_test = svm.SVC(kernel='linear') 
svm_model_test.fit(X_test, y_test) 
svm_prediction_test = svm_model_test.predict(X_test)
print ('svm_test:', np.mean(svm_prediction_test == y_test))
# Out:
# svm_test: 1.0

# %%
from sklearn.ensemble import RandomForestClassifier  
RF_model_test = RandomForestClassifier(max_depth=2, random_state=0)
RF_model_test.fit(X_test, y_test) 
RF_prediction_test = RF_model_test.predict(X_test)
print ('RandomForest_test:', np.mean(RF_prediction_test == y_test))
# Out:
# RandomForest_test: 0.791666666667

# %%
from sklearn.linear_model import SGDClassifier
SGD_model_test = SGDClassifier()
SGD_model_test.fit(X_test, y_test) 
SGD_prediction_test = SGD_model_test.predict(X_test)
print ('SGD_test:', np.mean(SGD_prediction_test == y_test))
# Out:
# SGD_test: 1.0
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_model_test = DecisionTreeClassifier(max_depth = 2).fit(X_test, y_test)
dtree_predictions_test = dtree_model_test.predict(X_test)
print ('DT_test:', np.mean(dtree_predictions_test == y_test))

from sklearn.neighbors import KNeighborsClassifier
knn_test = KNeighborsClassifier(n_neighbors = 7).fit(X_test, y_test)
knn_predictions_test = knn_test.predict(X_test) 
print ('knn_test:', np.mean(knn_predictions_test == y_test))
# Out:
# DT_test: 0.691666666667
# knn_test: 0.958333333333

# %%
"""for i in range(20):
    print ('>>>>>>>>>>>.',RF_model.predict(jdres_test_vectors[i]))
    print (jdres_test_labels[i])"""

for i in range(600):
    print ('>>>>>>>>>>>.',svm_model.predict(train_vectors[i]))
    print (data_labels[i])
# Out:
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others

# %%
for i in range(120):
    print('>>>>>>>>>>>.',SGD_model_test.predict(X_test[i])) 
    print (y_test[i])
# Out:
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['IT']
# IT
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['software']
# software
# >>>>>>>>>>>. ['content writer']
# content writer
# >>>>>>>>>>>. ['others']
# others
# >>>>>>>>>>>. ['software']
# software

# %%
svm_model_check = svm.SVC(kernel='linear') 
svm_model_check.fit(X_train, y_train) 
svm_prediction_check = svm_model_check.predict(X_test)
print ('svm_test:', np.mean(svm_prediction_check == y_test))
# Out:
# svm_test: 0.966666666667

# %%
SGD_model_check = SGDClassifier()
SGD_model_check.fit(X_train, y_train) 
SGD_prediction_check = SGD_model_check.predict(X_test)
print ('SGD_test:', np.mean(SGD_prediction_check == y_test))
# Out:
# SGD_test: 0.975
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.ensemble import RandomForestClassifier  
RF_model_test = RandomForestClassifier(max_depth=2, random_state=0)
RF_model_test.fit(X_train, y_train) 
RF_prediction_test = RF_model_test.predict(X_test)
print ('RandomForest_test:', np.mean(RF_prediction_test == y_test))

from sklearn.tree import DecisionTreeClassifier
dtree_model_check = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train)
dtree_predictions_check = dtree_model_check.predict(X_test)
print ('DT_test:', np.mean(dtree_predictions_check == y_test))

from sklearn.neighbors import KNeighborsClassifier
knn_check = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
knn_predictions_check = knn_check.predict(X_test) 
print ('knn_test:', np.mean(knn_predictions_check == y_test))
# Out:
# RandomForest_test: 0.808333333333
# DT_test: 0.683333333333
# knn_test: 0.975

# %%
target_names=['Resume', 'JobDescription']

# %%
y_pred = svm_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      0.90      0.95        29
# JobDescription       0.97      1.00      0.99        33
#
#    avg / total       0.97      0.97      0.97       120
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 4, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
y_pred = RF_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.92      0.76      0.83        29
# JobDescription       0.96      0.79      0.87        33
#
#    avg / total       0.83      0.81      0.81       120
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 4, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
y_pred = SGD_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      0.93      0.96        29
# JobDescription       1.00      0.97      0.98        33
#
#    avg / total       0.97      0.97      0.97       120
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 4, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
y_pred = dtree_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.43      0.97      0.60        29
# JobDescription       1.00      0.85      0.92        33
#
#    avg / total       0.62      0.68      0.62       120
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 4, does not match size of target_names, 2
#   .format(len(labels), len(target_names))
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      0.93      0.96        29
# JobDescription       0.97      0.97      0.97        33
#
#    avg / total       0.98      0.97      0.97       120
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 4, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
SGD_model_test.predict(test_file)[0]
# Out:
# 'software'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
svm_model.predict(test_file)[0]
# Out:
# 'others'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])

RF_model.predict(test_file)[0]
# Out:
# 'software'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
dtree_model.predict(test_file)[0]
# Out:
# 'IT'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
knn.predict(test_file)[0]
# Out:
# 'software'
