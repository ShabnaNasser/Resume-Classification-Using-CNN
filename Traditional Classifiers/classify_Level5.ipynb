# %%
import nltk, pickle, string
from nltk.corpus import stopwords
import re
import os
from tika import parser
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences


from textblob.classifiers import NaiveBayesClassifier as NBC
from textblob import TextBlob

# %%
def clean_doc(doc):
    """
    Cleaning a document by several methods:
        - Lowercase
        - Removing whitespaces
        - Removing stopwords
        - Removing punctuations
        
    """
    stop_words = set(stopwords.words('english'))
    
    # Lowercase
    doc = doc.lower()
   
    tokens = doc.translate({ord(c):"" for c in "\u200b\uf020\u2028\xa0\uf0e0\uf095\uf041\uf0e1\uf0b7\xad"})
    tokens = tokens.translate({ord(c):" " for c in "[):,·](;•●■♦▪"})
    tokens = tokens.translate({ord(c):"f" for c in "�"})
    
    # Removing multiple whitespaces
    tokens = re.sub(r"\?", " \? ", tokens)
    
    # Split in tokens
    tokens = tokens.split()
    
    # Remove Stopwords
    tokens = [w for w in tokens if not w in stop_words]
    # Remove punctuation
    tokens = [w.translate(str.maketrans('', '', string.punctuation)) for w in tokens]
    
    return ' '.join(tokens)

# %%
def LoadData_level5():
    label_level5=[]
    i=0
    for foldername in os.listdir("/home/shabna/Desktop/example_codes/new_sample/level5/developer"):
        for file in os.listdir("/home/shabna/Desktop/example_codes/new_sample/level5/developer/"+foldername):
    
            try:
                print (i, foldername, file)
                parsedPDF = parser.from_file("/home/shabna/Desktop/example_codes/new_sample/level5/developer/"+foldername+"/"+file)

                resume_contents=clean_doc(parsedPDF['content'])
            #Data = resume_contents.encode('utf-8')    
                label_level5.append((resume_contents,foldername))
            except UnicodeEncodeError:
                print ('Unicode error:', file)
            i=i+1
    #print (label_resume)
    return(label_level5)

# %%
label_level5=LoadData_level5()
# Out:
# 0 php reshmakr.pdf
# 1 php MAYAARJUNAN[1_0].docx
# 2 php arifca[5_1].pdf
# 3 php BinsBabu.pdf
# 4 php priyankaphilip[1_4].pdf
# 5 php VanithaB[1_9].docx
# 6 php seshasaikotapati[7_0].doc
# 7 php vijay_koogu_Bengaluru___Bangalore_7.03_yrs.docx
# 8 php Anju K N.docx
# 9 php pankaj_shukla_Nagpur_10.01_yrs.doc
# 10 php NaheedaKamarudheen_Resume.pdf
# 11 php Ranjit_Kumar_Delhi_Region_7.08_yrs.doc
# 12 php Sheethal PHP,Codeigniter,Wordpress.doc
# 13 php Anand_Arunachalam_Chennai_5.06_yrs.doc
# 14 php rajesh_vishwakarma_Delhi_Region_8.00_yrs.doc
# 15 php panchalkeval[1_10].pdf
# 16 php ASHIK cV.pdf
# 17 php saranya_v_Chennai_6.03_yrs.doc
# 18 php Ajay_kumar_singh__Bengaluru___Bangalore_12.00_yrs.doc
# 19 php MohdSamiullah[3_6].doc
# 20 php sajeevsomanathan[2_11].docx
# 21 php Sachin_Talan_Delhi_10.00_yrs.pdf
# 22 php SAINADHKOTINADHAM[1_6].docx
# 23 php VijayabanuS[1_0].pdf
# 24 php 84632746_Gurgaon_2.05_yrs.pdf
# 25 php DONAJOHNN[3_1].docx
# 26 php sneha_harihar_Bengaluru___Bangalore_2.07_yrs.pdf
# 27 php ASWATHYVIJAYAN[4_0].pdf
# 28 php TonyThomas[4_4].pdf
# 29 php VINOBHA[3_7].docx
# 30 php JOSEPHSTANLEYDS[2_9].pdf
# 31 php sajanajoy[1_5].docx
# 32 php Manoj_Kumar_Gupta_Noida_12.00_yrs.docx
# 33 php Sruthy K.pdf
# 34 php GLAISE BABY.doc
# 35 php ReemaCPaul[5_0].pdf
# 36 php RajaPonRaniS[2_0].pdf
# 37 php swarnadeepan[2_0].docx
# 38 php dhirendra_mishra_Mumbai_2.04_yrs.docx
# 39 php AustinAbrahamA[1_10].pdf
# 40 php AbdulAffar[2_2].pdf
# 41 php Rsureshkumar[4_4].pdf
# 42 php SHIJU THOMAS.doc
# 43 php Surendra_Yadav_Bhopal_9.01_yrs.doc
# 44 php AJITHKP[2_0].pdf
# 45 php DiyaSebastian[2_8].docx
# 46 php varanambigai[2_10].docx
# 47 php VenkateshVanapalli[4_3].doc
# 48 php mallelareddy[3_1].doc
# 49 php Antonythomas[1_6].pdf
# 50 php devidas[1_6].pdf
# 51 php S Ashiq.pdf
# 52 php Shashi_Kant_Mishra_Bengaluru___Bangalore_10.08_yrs.pdf
# 53 php ArunKumarD[5_3].docx
# 54 php SreejithS[7_0].pdf
# 55 php Revathy.pdf
# 56 php bhavana_sathaykeerthi_Bengaluru___Bangalore_8.00_yrs.doc
# 57 php AlfyGeorge[1_1].docx
# 58 php shyamkumar[1_6].doc
# 59 php 82141837_India_12.00_yrs.docx
# 60 php Piyush_Handa_Noida_8.00_yrs.docx
# 61 php RISHIKESHKUMARTB[9_0].doc
# 62 php sushmita_Chakraborty_Bengaluru___Bangalore_13.00_yrs.doc
# 63 php SaleeshPP[2_3].doc
# 64 php mark_bame_martires_Philippines_8.04_yrs.pdf
# 65 php SREEJAJS[5_5].doc
# 66 php Amit_Shah_Singapore_12.11_yrs.doc
# 67 php SheikSFaheenAhmed[2_10].docx
# 68 php Sukhithk[4_11].doc
# 69 php JD PHP.txt
# 70 php oommen_peter_n_PHP.pdf
# 71 php AneeshRKurup[7_0].doc
# 72 php Shintu.docx
# 73 php ArunKJacob[1_8].pdf
# 74 php Rajnikant_bajpai___Nagpur_4.00_yrs.doc
# 75 php RakhiRaj[2_6].pdf
# 76 php Sanjay_Pillai_Hyderabad_-_Secunderabad_6.05_yrs.pdf
# 77 php AJITHMOHAN[2_6].pdf
# 78 php Juby_PHP.pdf
# 79 php JeminJames[3_0].docx
# 80 php Rakesh[2_2].docx
# 81 php BaluchandarKarri[1_6].docx
# 82 php Pradeep_Singhal_Jaipur_8.00_yrs.doc
# 83 php SHINTUV[3_0].docx
# 84 php SREEKALACS[3_1].docx
# 85 php RijoPaul[4_9].docx
# 86 php VinuCS[1_10].pdf
# 87 php RoopeshVV[2_0].docx
# 88 php Anjuskurup[2_1].docx
# 89 php RijoMP-Resume.docx
# 90 php UssainRaswi[0_7].pdf
# 91 php Bipin S Nair.pdf
# 92 php Davinder_Kumar_Gurgaon_4.11_yrs.docx
# 93 php anuroopfrancis[3_6].pdf
# 94 php ShimnaPV[8_0].doc
# 95 php Shalini[0_11].docx
# 96 php DIJITHKUMARP[3_5].docx
# 97 php RahulCS[3_4].docx
# 98 php KalimuthuP[4_5].doc
# 99 php VineethaMS[2_0].doc
# 100 php shijint[3_6].doc
# 101 php Rituparna_Chakraborty_Kolkata_1.01_yrs.docx
# 102 php SibinA[0_5].pdf
# 103 php Shanmugavel[8_0].pdf
# 104 php Hema[4_2].docx
# 105 php sooryadasmk[1_1].pdf
# 106 php 84635751_Pune_9.00_yrs.doc
# 107 php TAMILSELVANM[5_0].docx
# 108 php ZEESHANUR_RAHMAN_Delhi_5.03_yrs.pdf
# 109 php Darshit_Khatri_Mumbai_8.06_yrs.doc
# 110 php Sri_Rao__Malaysia_3.00_yrs.doc
# 111 php athirasubair.pdf
# 112 php ShahulH[5_1].doc
# 113 php PARIMALSHARMA[5_6].docx
# 114 php SajinR[2_1].docx
# 115 php RAHUL_KADAV_Mumbai_7.11_yrs.doc
# 116 php vijayaramreddy[2_8].doc
# 117 php PrabhakaranSeenivasan[3_5].docx
# 118 php VidhyaRadhakrishnan[4_4].docx
# 119 php FATHIMATH SAJILAV.docx
# 120 php JEGADEESH[3_5].pdf
# 121 php VinshaKP[3_8].pdf
# 122 php VipinKumarKM[5_9].docx
# 123 php Senthil Kumaran S.doc
# 124 php SabnaKS[2_0].doc
# 125 php naveenkumarkolla[2_6].docx
# 126 php Karthik[7_0].pdf
# 127 php DeenaDavis[1_3].pdf
# 128 php athiradeviKR[1_8].docx
# 129 php Peppin_Shaju_Chennai_8.00_yrs.doc
# 130 php SWETHAVK[1_4].docx
# 131 php Sreenivasa_Murthy_Chennai_12.07_yrs.doc
# 132 php Ganesh_Yewale__Pune_3.00_yrs.docx
# 133 php TintuMathew.docx
# 134 php Prasad_N_Bengaluru___Bangalore_7.05_yrs.docx
# 135 php Sanchi_Varma_Delhi_5.00_yrs.pdf
# 136 php ANANDHAKUMARM[3_7].doc
# 137 php RAJKUMAR[4_7].doc
# 138 php srikanth_sriram_Hyderabad___Secunderabad_3.00_yrs.doc
# 139 php Santosh_Kumar_Hyderabad___Secunderabad_10.00_yrs.doc
# 140 php Neeraj_Sukheja_Bhopal_5.05_yrs.docx
# 141 php GinjoJohny[2_7].doc
# 142 php ReshmaBoban_PHP_Fresher.PDF
# 143 php Saranya M.S.pdf
# 144 php Resume_Kiran.doc
# 145 php sojuvarughesethomas[2_3].docx
# 146 php shreya_choudhary_Bengaluru___Bangalore_2.00_yrs.doc
# 147 php RAJAMANICKAMS[3_0].docx
# 148 php VelmuruganM[1_6].pdf
# 149 php SYAMILIMOLKV[2_1].docx
# 150 dotnet Srividhya_Krishnamoorthy_Bengaluru___Bangalore_3.11_yrs.docx
# 151 dotnet Nikita_Kathale_Mumbai_3.06_yrs.doc
# 152 dotnet Yogesh_Nikam_Pune_5.00_yrs.doc
# 153 dotnet tatayyababu_kasani_Hyderabad___Secunderabad_2.02_yrs.docx
# 154 dotnet PRASANTH_JACOB_KOSHY_Cochin___Kochi___Ernakulam_4.11_yrs.doc
# 155 dotnet Anishkumar_A.doc
# 156 dotnet Anish_Paul_Cochin___Kochi___Ernakulam_4.00_yrs.doc
# 157 dotnet ARUN_PADMANNAVAR_Bengaluru___Bangalore_4.00_yrs.docx
# 158 dotnet syed_omar_azam_Hyderabad___Secunderabad_3.04_yrs.doc
# 159 dotnet Pragati_Salvekar_Pune_3.01_yrs.docx
# 160 dotnet Santhosh_Kumar__Chennai_5.00_yrs.docx
# 161 dotnet Roopesh_Resume.pdf
# 162 dotnet Aravind_R_S.pdf
# 163 dotnet ResumeRaveesh.docx
# 164 dotnet Mohsin_Inamdar_Navi_Mumbai_3.03_yrs (1).docx
# 165 dotnet Arun_P_S_Cochin___Kochi___Ernakulam_3.04_yrs.pdf
# 166 dotnet Bernaditta Oshin Hogan CV.docx
# 167 dotnet RONY JOSEPH (2).doc
# 168 dotnet RinshaFrancis-3.6 yrs.docx
# 169 dotnet Siva .pdf
# 170 dotnet ATHIRA_P.R_Cochin___Kochi___Ernakulam_3.00_yrs.docx
# 171 dotnet Neerkunnam_P_O.pdf
# 172 dotnet Praveen GS.doc
# 173 dotnet JOBIN JOSEPH.doc
# 174 dotnet ANAND HARIDAS.doc
# 175 dotnet Rajesh_Mudedla_Chennai_3.01_yrs.docx
# 176 dotnet Prashant_Biradar_Bengaluru___Bangalore_3.02_yrs.doc
# 177 dotnet Naseef_Kabeer_Cochin___Kochi___Ernakulam_4.00_yrs.doc
# 178 dotnet Dotnet - JD.docx
# 179 dotnet kaviarasu_yuvaraj_Chennai_3.06_yrs.doc
# 180 dotnet Dhanashree_Wagal_Mumbai_4.01_yrs.docx
# 181 dotnet raghavendra_s_Bengaluru___Bangalore_4.10_yrs.doc
# 182 dotnet Neeraj R.doc
# 183 dotnet Premraj_S_Cochin___Kochi___Ernakulam_3.00_yrs.doc
# 184 dotnet Suraj_Mhetre__Mumbai_2.00_yrs.pdf
# 185 dotnet Remyamol R - 6 YRS-rejected.doc
# 186 dotnet Cronin_George_Cochin___Kochi___Ernakulam_4.05_yrs.doc
# 187 dotnet MUNNA_KUMAR__Bengaluru___Bangalore_3.05_yrs.doc
# 188 dotnet Sk_Ajaruddin_Ali_Kolkata_3.06_yrs.doc
# 189 dotnet premchand - MBA- rEJECT.doc
# 190 dotnet RenyRobert - 2 YRS.docx
# 191 dotnet udaya_kumar_Chennai_5.00_yrs.doc
# 192 dotnet SAPTARSHI__Kolkata_4.00_yrs.doc
# 193 dotnet Bejoy_Alson_Cochin___Kochi___Ernakulam_3.10_yrs.doc
# 194 dotnet Sherin_joy_Cochin___Kochi___Ernakulam_4.02_yrs.doc
# 195 dotnet prudhvi_raj_aravapalli_Chennai_3.03_yrs.doc
# 196 dotnet Abdul Salam KA.doc
# 197 dotnet Sujith.docx
# 198 dotnet Nidhish_Nair_S_M_Thiruvananthapuram___Trivandrum_3.05_yrs (1).doc
# 199 dotnet Vineeth___Cochin___Kochi___Ernakulam_4.02_yrs.pdf
# 200 dotnet ashwini_kale_Mumbai_City_4.02_yrs.pdf
# 246 dotnet ResumeNew.docx
# 247 dotnet JESMI A M.doc
# 248 dotnet dotnet.pdf
# 249 dotnet Gaurav_Balyan_Noida_4.11_yrs.docx
# 250 dotnet Kurban_Qureshi___Mumbai_4.00_yrs.docx
# 251 dotnet Rajendrakumar_Balasubramanian_Chennai_4.04_yrs.doc
# 252 dotnet Nandini_Gaur_Mumbai_4.02_yrs.doc
# 253 dotnet Aisha_Ashraf_India_3.01_yrs.doc
# 254 dotnet NIRBHAY_PANDEY_Noida_3.03_yrs (1).docx
# 255 dotnet SANOOP.M.P.doc
# 256 dotnet RANJAN_SIKDAR_Kolkata_3.06_yrs.pdf
# 257 dotnet RAMBABU__Hyderabad___Secunderabad_4.05_yrs (1).doc
# 258 dotnet Revathi B Nair.pdf
# 259 dotnet KIRAN_KUMAR_Cochin___Kochi___Ernakulam_3.05_yrs.docx
# 260 dotnet Rakesh_V_Chandran_Cochin___Kochi___Ernakulam_5.00_yrs.doc
# 261 dotnet Srinivasa_Rao_K_Hyderabad___Secunderabad_4.01_yrs.docx
# 262 dotnet Lekshmi Sadanandan.doc
# 263 dotnet Resume_Roshan George V_MCA_Experienced_ASPNet_C#.pdf
# 264 dotnet Ramlingesh_H_Bengaluru___Bangalore_4.02_yrs.doc
# 265 dotnet Rachna__Mohali_5.00_yrs.pdf
# 266 dotnet Pankhuri_Jain_Kolkata_4.01_yrs.doc
# 267 dotnet JITHIN PK.pdf
# 268 dotnet Biju_Mehan_Dhas__Thiruvananthapuram___Trivandrum_3.07_yrs (1).docx
# 269 dotnet Purushothaman_S_Chennai_3.11_yrs.docx
# 270 dotnet vishal_sonekar_Pune_4.07_yrs.doc
# 271 dotnet Mohammad_Asif_Singapore_5.00_yrs.docx
# 272 dotnet Resume_VipinVKartha-3.pdf
# 273 dotnet Ajay_V_Raj_Thiruvananthapuram___Trivandrum_5.00_yrs.pdf
# 274 dotnet Saikumar_Bandaru_Mysore_3.04_yrs.docx
# 275 dotnet SHAIK NASEER HUSSAIN.doc
# 276 dotnet Ankarao.doc
# 277 dotnet Kiran.doc
# 278 dotnet Abhijeet_Khandagale_Pune_3.09_yrs.pdf
# 279 dotnet Arun ks.doc
# 280 dotnet Renita_Albin-Resume.docx
# 281 dotnet ALOK B. KRISHNAN.doc
# 282 dotnet Saurabh_Khandelwal_Pune_4.00_yrs.doc
# 283 dotnet Deepak_Jain_Indore_3.00_yrs.doc
# 284 dotnet SELVA_LENIN_Cochin___Kochi___Ernakulam_4.01_yrs.doc
# 285 dotnet shanmuki_p_India_4.01_yrs.docx
# 286 dotnet binu babu (resume).docx
# 287 dotnet Snehalaltv  .pdf
# 288 dotnet Neha_Kulashri__Pune_3.07_yrs.docx
# 289 dotnet Praveen. K.doc
# 290 dotnet Aashidh.pdf
# 291 dotnet rupesh_watkar_Pune_4.02_yrs.docx
# 292 dotnet Rohit_Ramdas_Nichit__Nasik_3.05_yrs.docx
# 293 dotnet Anu_Sathyanathan_CV- Reject.doc
# 294 dotnet Ajay_ NET Developer.docx
# 390 pythondjango Mayank_Sharma_Gurgaon_3.01_yrs.pdf
# 391 pythondjango Rohit_Salunke_Pune_2.01_yrs.pdf
# 392 pythondjango 64032445_Mumbai_4.00_yrs.pdf
# 393 pythondjango NARRAMAHENDERREDDY[2_7].docx
# 394 pythondjango A.KRISHNA_REDDY_Hyderabad_-_Secunderabad_7.00_yrs.pdf
# 395 pythondjango ArunK[4_3].pdf
# 396 pythondjango AkhilKA[2_9].pdf
# 397 pythondjango ashish_anand_Chandigarh_6.11_yrs.docx
# 398 pythondjango HaridasanPC[6_0].docx
# 399 pythondjango Soumyaranjan[2_5].docx
# 400 pythondjango Gauri_kulkarni_Pune_1.07_yrs.pdf
# 401 pythondjango GaneshManturi[4_4].docx
# 402 pythondjango Mahesh_N_Hyderabad___Secunderabad_2.02_yrs.doc
# 403 pythondjango harikesh_patel_Bengaluru_-_Bangalore_6.02_yrs.docx
# 404 pythondjango JithinPrakash[2_4].pdf
# 405 pythondjango Mohan[4_1].docx
# 406 pythondjango shibiraj__resume.pdf
# 407 pythondjango Bhagyashri_Gite_Pune_2.00_yrs.docx
# 408 pythondjango NIKHIL KRISHNAN.doc
# 409 pythondjango Ottigunta_Jyothi_Naidu_India_4.02_yrs.docx
# 410 pythondjango VimalKesavan[3_11].docx
# 411 pythondjango SVINOTHKUMAR[4_8].docx
# 412 pythondjango veenaaravindc[2_5].docx
# 413 pythondjango Vineet_kumar_Dubey_Mumbai_4.10_yrs.pdf
# 414 pythondjango SarathKumarJ[3_7].pdf
# 415 pythondjango SELVAKUMAR.L.doc
# 416 pythondjango ajayjayaram[3_6].docx
# 417 pythondjango nivin_paul_Qatar_4.00_yrs.docx
# 418 pythondjango RobertFernandes[2_8].docx
# 419 pythondjango nripesh_agarwal_Delhi_6.06_yrs.pdf
# 420 pythondjango 47731129_Bengaluru_-_Bangalore_6.00_yrs.docx
# 421 pythondjango NewResume-Sandeep docx.pdf
# 422 pythondjango Amit_kumar_singh_Lucknow_4.06_yrs.docx
# 423 pythondjango Gajender_singh_Delhi_11.02_yrs.docx
# 424 pythondjango 52559549_Hyderabad_-_Secunderabad_4.00_yrs.docx
# 425 pythondjango Vikram Prasanna.docx
# 426 pythondjango SudheeshS[3_0].pdf
# 427 pythondjango sreelekshmims[3_5].pdf
# 428 pythondjango sovinjose[5_0].pdf
# 429 pythondjango GaneshKumar[2_0].doc
# 430 pythondjango Jisson Varghese.doc
# 431 pythondjango 77522138_Pune_4.09_yrs.doc
# 432 pythondjango venkateshwarareddy[2_0].doc
# 433 pythondjango sudeepkrishnan[2_6].doc
# 434 pythondjango sarathcp[3_0].pdf
# 435 pythondjango Pankesh_kumar_Gurgaon_6.00_yrs.pdf
# 436 pythondjango bijal_maniar_Mumbai_5.00_yrs.docx
# 437 pythondjango Vijeeshk[6_0].pdf
# 438 pythondjango RamprasadB[4_0].docx
# 439 pythondjango waseem[3_1].doc
# 440 pythondjango praveen_kumar_s__Bengaluru___Bangalore_2.02_yrs.docx
# 582 android ANOOP V.doc
# 583 android YashSrivastavaProfile.pdf
# 584 android SunilKumarProfile.pdf
# 585 android ManishikaSinghProfile.pdf
# 586 android HarpreetKaurProfile.pdf
# 587 android NitinJain[2_5].docx
# 588 android AnkitapalProfile.pdf
# 589 android JayKikaniProfile.pdf
# 590 android NehaJohariProfile.pdf
# 591 android SijuDharmadevan[6_0].doc
# 592 android AnupkumarShuklaProfile.pdf
# 593 android sumanmajumder[3_2].doc
# 594 android Vrinda[3_0].docx
# 595 android Joice P Joy- Reject.doc
# 596 android VipinVasu.pdf
# 597 android NIKITAMARYSOLOMAN[1_7].pdf
# 598 android Vinaye.doc
# 599 ios ManikandanVNair[2_3].docx
# 600 ios FAHAD-rejected.docx
# 601 ios Dimil T Mohan_IOS Developer.pdf
# 602 ios SugumaranM[4_5].doc
# 603 ios Harikrishnapanicker.doc
# 604 ios JubySaraKuruvilla[2_8].pdf
# 605 ios Amol_Ramdas_Pawar___Pune_2.00_yrs.doc
# 606 ios Benarji_Chowdari_Y_Hyderabad___Secunderabad_2.01_yrs.pdf
# 607 ios Arun_Singh_Bengaluru___Bangalore_1.08_yrs.pdf
# 608 ios Arindam_Ghosh_Kolkata_6.10_yrs.docx
# 609 ios Rafeek Resume doc docx.pdf
# 610 ios Ramu[4_6].doc
# 611 ios Ambili B Menon.doc
# 612 ios AbinBaby.pdf
# 613 ios KarthikP[2_7].docx
# 614 ios Ajaykumar_Mishra_Nashik_2.04_yrs.docx
# 615 ios UNNIKRISHNANP[7_0].docx
# 616 ios RoshnaDsouza[5_0].pdf
# 617 ios SarathRaveendran[3_0].pdf
# 618 ios 55778200_Bengaluru___Bangalore_2.01_yrs.pdf
# 619 ios Ebin Dominic_iOS.docx
# 620 ios Britto Thomas.docx
# 621 ios RINCE[5_6].doc
# 622 ios harishthadandla[2_0].docx
# 623 ios BIJU GEORGE- Reject.doc
# 624 ios MohamedRafiBA[4_9].doc
# 625 ios srinu[3_2].doc
# 626 ios SaravananM[1_3].docx
# 627 ios balaram_somineni_Hyderabad___Secunderabad_2.00_yrs.docx
# 628 ios ImranMohammed - Reject.doc
# 629 ios JamalAhamad[2_3].doc
# 630 ios NeerajKumarMishra[3_0].doc
# 631 ios vamshi[6_0].doc
# 632 ios 72290504_Noida_1.00_yrs.doc
# 633 ios SANTHOSHKUMAR[3_0].doc
# 634 ios BollaSrinivas[2_3].pdf
# 635 ios Ashokkumar_Subramanian_Chennai_0.06_yrs.docx
# 636 ios DONIYAJOY[3_0].pdf
# 637 ios Ami_Intwala__Ahmedabad_1.05_yrs.pdf
# 638 ios AkhilaTVellanikaran[2_0].docx
# 639 ios NikhilBKuriakose[2_0].pdf
# 640 ios RMahesh[2_9].docx
# 641 ios Nibin Varghese.docx
# 642 ios VibinPV[6_0].pdf
# 643 ios SREEDEVISUBRAMANIAN[3_3].docx
# 644 ios SaliniSebastian[7_0].doc
# 645 ios mumthasir[4_6].pdf
# 646 ios SarigaResume - NI.docx
# 647 ios MartinJacob[6_0].pdf
# 648 ios MARYSONNETXAVIER[3_1].pdf
# 649 ios Manoj Nair.doc
# 650 ios alekhya[5_3].docx
# 651 ios 82299682_Chandigarh_0.06_yrs.docx
# 652 ios DeepuStanly[1_1].docx
# 653 ios Ambili m v.doc
# 654 ios ArunkumarVR - Reject.pdf
# 655 ios AiswaryalatestResume.docx.pdf
# 656 ios DineshKumarM[3_0].doc
# 657 ios RajaSekhar[5_5].docx
# 658 ios JincyWalston[2_2].doc
# 659 ios balai03.doc
# 660 ios Rijesh K R.doc
# 661 ios praveenkumar[2_0].docx
# 662 ios RoshniVarghese[3_3].docx
# 663 ios Anil K.doc
# 664 ios akshay_chinthakayla_India_2.00_yrs.pdf
# 665 ios Bharathkumarreddy[4_3].doc
# 666 ios Abhishek_Jaiswal_Chennai_6.00_yrs.pdf
# 667 ios VijayKumay[3_4].docx
# 668 ios BenAntonyPR[4_7].pdf
# 669 ios Kanju Jiffry.doc
# 670 ios Harish[3_0].pdf
# 671 ios Muhammed Rafeek K A- offer declined.doc
# 672 ios saravanakumar[4_6].docx
# 673 ios Jephin.doc
# 674 ios varunthomas[6_0].docx
# 675 ios Rajani[1_2].doc
# 676 ios Praveen[6_0].doc
# 677 ios 81940699_Bengaluru___Bangalore_2.00_yrs.pdf
# 678 ios Amol_Ambhure_Pune_2.00_yrs.pdf
# 679 ios G Saia Swanth[.pdf
# 680 ios SANKAREVANTH[1_8].pdf
# 681 ios ArunkumarPorchezhiyan[3_9].docx
# 682 ios Krushnamma[2_9].doc
# 683 ios veeraprakash[5_5].docx
# 684 ios muraliyandapalli[2_7].doc
# 685 ios Vikesh[2_3].pdf
# 686 ios satishkumar[2_2].pdf
# 687 ios DinoopRajT[5_6].docx
# 688 ios Deepika HV.docx
# 689 ios Arshwin_Denuev_Lal_P.M_Cochin___Kochi___Ernakulam_2.01_yrs.pdf
# 690 ios Cethal.doc
# 691 ios AneeshKA[2_0].docx
# 692 ios Dipin.K.doc
# 693 ios SUBINSURESHNAIRKT.pdf
# 694 ios 76146783_Hyderabad___Secunderabad_3.00_yrs.docx
# 695 ios PratheeshPrabhakaran[7_0].doc
# 696 ios Deepesh_Naik_Goa_4.00_yrs.pdf
# 697 ios LUBAVARGHESE[3_6].pdf
# 698 ios Deepak_Ghadi__Mumbai_0.08_yrs.docx
# 699 ios Nijiljose[3_4].docx
# 700 ios Akhil P D - Reject.docx
# 701 ios srinivas[2_1].docx
# 702 ios Arun_Pareek_Hyderabad___Secunderabad_4.10_yrs.pdf
# 703 ios vinathy[2_2].pdf
# 704 ios VINEETHM[3_7].pdf
# 705 ios RAHUL R.doc
# 706 ios VamsiMullapudi[3_2].pdf
# 707 ios Sivarajselvaraj[4_0].docx
# 708 ios Ardra Thambi - Mac.doc
# 709 ios Ankita_Satpathy_Bengaluru___Bangalore_2.03_yrs.pdf
# 710 ios deepthi___Bengaluru___Bangalore_4.00_yrs.pdf
# 711 ios SavithaKuduma[2_6].docx
# 712 ios RukminiKR[4_4].pdf
# 713 ios SUJITHRA- Reject.docx
# 714 ios Anil_Kumar_Nomula_Hyderabad___Secunderabad_0.06_yrs.pdf
# 715 ios 51361326_Bengaluru___Bangalore_2.08_yrs.docx
# 716 ios AjithCPurushothaman[3_4].docx
# 717 ios DyanaAVarghese.doc
# 718 ios Dipendra_Dubey_Mumbai_City_5.06_yrs.docx
# 719 ios 60659278_Bengaluru___Bangalore_4.05_yrs.docx
# 720 ios Arun Kurian Ninan.doc
# 721 ios Usha[1_1].docx
# 722 ios THOMASPAUL[3_5].pdf
# 723 ios Beneesh Baby- Reject.doc
# 724 ios praveendavis[3_0].doc
# 725 ios ArjunPA[1_1].docx
# 726 ios vikasbharat[1_3].docx
# 727 ios jacob -REJECT.pdf
# 728 ios Selvakumar[3_7].docx
# 729 ios 77596221_Mumbai_2.06_yrs.pdf
# 730 ios SrinivasuluMeenuga[2_7].docx
# 731 ios Ananthkumar[3_5].pdf
# 732 ios ArunKumar.pdf
# 733 ios Nouzil[2_3].docx
# 734 ios NeelBakshi[2_3].pdf
# 735 ios KPremSai[2_10].docx
# 736 ios JananiVasudev[2_11].doc
# 737 ios 58380646_Chennai_1.00_yrs.pdf
# 738 ios BetsyCBaby.pdf
# 739 ios mohdarshadali[1_6].doc
# 740 ios AlexBabu[2_3].pdf
# 741 ios Binso.pdf
# 742 ios ShankarK[4_1].doc
# 743 ios VineethM- Reject.pdf
# 744 ios 53556009_Chennai_3.05_yrs.pdf
# 745 ios FAISALAZEEZ[1_6].pdf
# 746 ios ANANTHURKRISHNAN[3_0].docx
# 747 ios Raghuram[1_8].pdf
# 748 ios Ashwin_Kumar_Sarangula__Hyderabad___Secunderabad_2.05_yrs.pdf
# 749 corejava B.RAMBABU__Hyderabad___Secunderabad_0.00_yrs.doc
# 750 corejava Kalavathi_guna__Hyderabad___Secunderabad_13.00_yrs.doc
# 751 corejava AravindPS.pdf
# 752 corejava raju_palanisamy_Chennai_3.05_yrs.docx
# 753 corejava SHAMEEM  A T.doc
# 754 corejava nirmal_barik_Mumbai_6.00_yrs.docx
# 755 corejava bejoy ks.pdf
# 756 corejava Bhaskar_Y_Hyderabad___Secunderabad_0.00_yrs.docx
# 757 corejava Nithi_Naik_Mumbai_5.02_yrs.doc
# 758 corejava 84017585_Pune_6.00_yrs.doc
# 759 corejava Praveen_Maurya_Noida_0.10_yrs.pdf
# 760 corejava Mahesh_Kumar_Tomar___Delhi_11.00_yrs.doc
# 761 corejava Akshay_Sherla_Pune_0.00_yrs.docx
# 762 corejava Debasishswain[2_6].doc
# 763 corejava Nageswararao_Eadara_Chennai_2.04_yrs.doc
# 764 corejava Revathy__Chennai_1.00_yrs.doc
# 765 corejava Rajendra_B_Hyderabad___Secunderabad_11.00_yrs.doc
# 766 corejava Rahul_Karnati___Hyderabad___Secunderabad_0.00_yrs.doc
# 767 corejava lakshmi_kota_Bengaluru___Bangalore_3.02_yrs.doc
# 768 corejava parag__Bengaluru___Bangalore_3.00_yrs.docx
# 769 corejava Rama_krishna_Bengaluru___Bangalore_3.00_yrs.docx
# 770 corejava pooja_k_Bengaluru___Bangalore_1.08_yrs.docx
# 771 corejava Naagendra_v_Hyderabad___Secunderabad_3.04_yrs.docx
# 772 corejava lalu_dash_Bengaluru___Bangalore_1.00_yrs.doc
# 773 corejava Naresh_Karimbakam_Bengaluru___Bangalore_9.06_yrs.doc
# 774 corejava Aditya_Jagtap_Pune_2.02_yrs.pdf
# 775 corejava Ravi_Kumar_Bengaluru___Bangalore_2.11_yrs.docx
# 776 corejava Rishu_Kumar_Bengaluru_-_Bangalore_3.01_yrs.doc
# 777 corejava Rekha_Madhuri_Hyderabad___Secunderabad_2.04_yrs.docx
# 778 corejava konduru_kiran_Bengaluru___Bangalore_3.00_yrs.doc
# 779 corejava Sriram__Chennai_3.04_yrs.docx
# 780 corejava Channabasappa__Bengaluru___Bangalore_8.09_yrs.docx
# 781 corejava Nasim_Akhtar_Bengaluru___Bangalore_5.05_yrs.doc
# 782 corejava JERITT K JOSE.doc
# 783 corejava mukesh_kumar_Delhi_0.00_yrs.doc
# 784 corejava Prabhath K V.docx
# 785 corejava ANEES_MS_Cochin_-_Kochi_-_Ernakulam_4.07_yrs.pdf
# 786 corejava ANOOP K.P.doc
# 787 corejava rajat_pathak__Delhi_1.07_yrs.doc
# 788 corejava Arvind_Kumar_Mumbai_9.03_yrs.doc
# 789 corejava KRISHNAMOHAN__Hyderabad___Secunderabad_3.07_yrs.doc
# 790 corejava Monish__Bengaluru___Bangalore_2.00_yrs.docx
# 791 corejava Amit_Gawande_Pune_10.06_yrs (2).doc
# 792 corejava MOHAMMED ASHHER.doc
# 793 corejava sanesh_resume.doc
# 794 corejava Sreejith.S.doc
# 795 corejava madhavi_t_Bengaluru___Bangalore_5.03_yrs.docx
# 796 corejava chandrasekhar_Vukku_Chennai_3.08_yrs.docx
# 797 corejava Lakshmi_Reddem_Hyderabad___Secunderabad_2.05_yrs.doc
# 798 corejava Mittapalli_Subramanyam_Bengaluru___Bangalore_0.00_yrs.pdf
# 799 corejava Sreeraj Ramachandran.doc
# 800 corejava Anish.pdf
# 801 corejava M. Shunmugaraj.doc
# 802 corejava chandrasekhar_thota_Pune_8.03_yrs.doc
# 803 corejava Samresh_Kumar_Bengaluru___Bangalore_6.00_yrs.doc
# 804 corejava Shaibu rahees.doc
# 805 corejava GOMATHYK[3_0].pdf
# 806 corejava Sanatan__Pune_7.08_yrs.docx
# 807 corejava Pramod_Kumar_Sharma_Ranchi_6.05_yrs.docx
# 808 corejava Aravind_Pal_Delhi_2.06_yrs.docx
# 809 corejava Shalini_Nair_Mumbai_4.06_yrs.doc
# 810 corejava ramu___Mumbai_5.00_yrs.doc
# 811 corejava mitali_khandelwal_Jaipur_0.00_yrs.docx
# 812 corejava GIJINA.R.doc
# 813 corejava Amit_Joshi_Noida_4.02_yrs (2).doc
# 814 corejava Mahadevan_M_Chennai_7.00_yrs.docx
# 815 corejava Pooja___Ahmedabad_1.00_yrs.doc
# 861 corejava JOHN PETER. R.doc
# 862 corejava Preethi_T__Bengaluru___Bangalore_3.00_yrs.docx
# 863 corejava MEENAL_pathre_Indore_2.04_yrs.doc
# 864 corejava Rachit_Agrawal_Noida_4.00_yrs.doc
# 865 corejava corejava.pdf
# 866 corejava Gulshan_Nayak_Bengaluru___Bangalore_2.05_yrs.docx
# 867 corejava SHANEESH M.doc
# 868 corejava gitanjali_zate_Pune_2.08_yrs.docx
# 869 corejava shaik_karimulla__Bengaluru_-_Bangalore_0.00_yrs.docx
# 870 corejava Gunja___Chennai_1.00_yrs.docx
# 871 corejava Roshni Kumar V.doc
# 872 corejava Gurmeet_Sindhu_Delhi_1.01_yrs.doc
# 873 corejava Riyash_D.pdf
# 874 corejava ashish_Bhakare_Pune_1.01_yrs.docx
# 875 corejava Johnmani_Das_Hyderabad___Secunderabad_4.03_yrs.docx
# 876 corejava akash_bawankar_Hyderabad___Secunderabad_3.05_yrs.doc
# 877 corejava Sanjid_T.pdf
# 878 corejava nilesh_bokhani_Bhuj_5.02_yrs.doc
# 879 corejava Sambasiva_Duddukuri_Bengaluru___Bangalore_4.06_yrs.docx
# 880 corejava Pavithra_K_Chennai_5.00_yrs.docx
# 881 corejava JAYAKUMAR_R_Coimbatore_1.05_yrs.doc
# 882 corejava BOBAN THOMAS_CoreJava.doc
# 883 corejava vinoth[6_0].doc
# 884 corejava saira_begum_Bengaluru___Bangalore_2.00_yrs.doc
# 885 corejava Nilesh_Patil_Pune_5.00_yrs.docx
# 886 corejava 1476458402073Resume_Shihad.pdf
# 887 corejava Priyanka_H_M__Bengaluru___Bangalore_0.00_yrs.docx
# 888 corejava Ayushi_Shinde_Pune_2.08_yrs.docx
# 889 corejava guru.s.pdf
# 890 corejava M_A_MASOOD_Hyderabad___Secunderabad_0.00_yrs.docx
# 891 corejava Saikrishna___Hyderabad___Secunderabad_0.00_yrs.doc
# 892 corejava sruthi_s_nair_Cochin___Kochi___Ernakulam_2.03_yrs.doc
# 893 corejava Saran_kumar_Bengaluru_-_Bangalore_1.00_yrs (2).doc
# 894 corejava Hari_Babu_Gopinathan_Bengaluru___Bangalore_9.06_yrs.docx
# 895 corejava prince_sachdeva_Noida_4.00_yrs.pdf
# 896 corejava Rajat_Singh_Mumbai_3.06_yrs.docx
# 897 corejava vinodvenugopal.pdf
# 898 corejava Adhish Bhoi.doc

# %%
len(label_level5)
# Out:
# 899

# %%
data_labels=[]
data=[]

for row in label_level5:
    data.append(row[0])
    data_labels.append(row[1])

# %%
print(len(data))
print(len(data_labels))
# Out:
# 899
# 899

# %%
print(len(data_labels))
# Out:
# 899

# %%
#labels = [0 for _ in range(len(label_resume))] + [1 for _ in range(len(label_jd))]
#print(labels)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=4, max_df=0.9)

# %%
# Apply model on jdres train data
train_vectors = vectorizer.fit_transform(data)
print(train_vectors)
# Out:
#   (0, 3381)	0.186271326985
#   (0, 2094)	0.0313239691787
#   (0, 6475)	0.0973226019218
#   (0, 1831)	0.0574194862076
#   (0, 3854)	0.0529730004528
#   (0, 262)	0.048862129676
#   (0, 4095)	0.0177240111536
#   (0, 3573)	0.0376674728779
#   (0, 1140)	0.0259788238111
#   (0, 4533)	0.0272970286085
#   (0, 5046)	0.0504664900693
#   (0, 4207)	0.0410591996127
#   (0, 6373)	0.0277191174703
#   (0, 6283)	0.0253514645305
#   (0, 6519)	0.0436970302224
#   (0, 5945)	0.0159805493838
#   (0, 861)	0.0479472971091
#   (0, 5820)	0.0162303711625
#   (0, 6618)	0.0158295162014
#   (0, 5549)	0.0680336700962
#   (0, 1835)	0.164580781481
#   (0, 4431)	0.208199983626
#   (0, 5128)	0.0582918181478
#   (0, 1002)	0.0217602247209
#   (0, 2592)	0.031822883524
#   :	:
#   (898, 5845)	0.145069557781
#   (898, 1024)	0.043459369624
#   (898, 3541)	0.0524774539908
#   (898, 3436)	0.154284062906
#   (898, 5477)	0.092371728209
#   (898, 2978)	0.11393602077
#   (898, 5385)	0.0378574964568
#   (898, 887)	0.0581650953935
#   (898, 898)	0.17856671533
#   (898, 552)	0.0549284986695
#   (898, 2402)	0.0629419658084
#   (898, 6455)	0.0629419658084
#   (898, 3416)	0.0581650953935
#   (898, 4340)	0.0629419658084
#   (898, 381)	0.183266835347
#   (898, 5150)	0.0595222384435
#   (898, 2680)	0.0595222384435
#   (898, 3255)	0.122177890231
#   (898, 3312)	0.124669949055
#   (898, 5919)	0.0629419658084
#   (898, 6482)	0.0450760197657
#   (898, 1667)	0.132226579465
#   (898, 3555)	0.12863532444
#   (898, 3269)	0.17856671533
#   (898, 5632)	0.0629419658084

# %%
X_train, X_test, y_train, y_test = train_test_split(train_vectors, data_labels, test_size=0.2, random_state=42)

# %%
svm_model = svm.SVC(kernel='linear') 
svm_model.fit(X_train, y_train) 
svm_prediction = svm_model.predict(X_train)
import numpy as np
print ('svm:', np.mean(svm_prediction == y_train))

'''for i in range(80):
    print ('>>>>>>>>>>>.',model.predict(train_vectors[i]))'''

    
from sklearn.ensemble import RandomForestClassifier  
RF_model = RandomForestClassifier(max_depth=2, random_state=0)
RF_model.fit(X_train, y_train) 
RF_prediction = RF_model.predict(X_train)
import numpy as np
print ('Random Forest:', np.mean(RF_prediction == y_train))

from sklearn.linear_model import SGDClassifier
SGD_model = SGDClassifier()
SGD_model.fit(X_train, y_train) 
SGD_prediction = SGD_model.predict(X_train)
import numpy as np
print ('SGD:', np.mean(SGD_prediction == y_train))

from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train,y_train)
dtree_predictions = dtree_model.predict(X_train)
print ('DT:', np.mean(dtree_predictions == y_train))


from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train,y_train)
knn_predictions = knn.predict(X_train) 
print ('knn:', np.mean(knn_predictions == y_train))
# Out:
# svm: 1.0
# Random Forest: 0.756606397775
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGD: 1.0
# DT: 0.488178025035
# knn: 0.966620305981

# %%
for i in range(900):
    print ('>>>>>>>>>>>.',RF_model.predict(X_train[i]))
    print (y_train[i])
print(len(y_train))

# %%
svm_model_test = svm.SVC(kernel='linear') 
svm_model_test.fit(X_test, y_test) 
svm_prediction_test = svm_model_test.predict(X_test)
print ('svm_test:', np.mean(svm_prediction_test == y_test))
# Out:
# svm_test: 1.0

# %%
from sklearn.ensemble import RandomForestClassifier  
RF_model_test = RandomForestClassifier(max_depth=2, random_state=0)
RF_model_test.fit(X_test, y_test) 
RF_prediction_test = RF_model_test.predict(X_test)
print ('RandomForest_test:', np.mean(RF_prediction_test == y_test))
# Out:
# RandomForest_test: 0.816666666667

# %%
from sklearn.linear_model import SGDClassifier
SGD_model_test = SGDClassifier()
SGD_model_test.fit(X_test, y_test) 
SGD_prediction_test = SGD_model_test.predict(X_test)
print ('SGD_test:', np.mean(SGD_prediction_test == y_test))
# Out:
# SGD_test: 1.0
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_model_test = DecisionTreeClassifier(max_depth = 2).fit(X_test, y_test)
dtree_predictions_test = dtree_model_test.predict(X_test)
print ('DT_test:', np.mean(dtree_predictions_test == y_test))

from sklearn.neighbors import KNeighborsClassifier
knn_test = KNeighborsClassifier(n_neighbors = 7).fit(X_test, y_test)
knn_predictions_test = knn_test.predict(X_test) 
print ('knn_test:', np.mean(knn_predictions_test == y_test))
# Out:
# DT_test: 0.538888888889
# knn_test: 0.988888888889

# %%
"""for i in range(20):
    print ('>>>>>>>>>>>.',RF_model.predict(jdres_test_vectors[i]))
    print (jdres_test_labels[i])"""

for i in range(300):
    print ('>>>>>>>>>>>.',svm_model.predict(train_vectors[i]))
    print (data_labels[i])
# Out:
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['pythondjango']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['dotnet']
# dotnet

# %%
for i in range(60):
    print('>>>>>>>>>>>.',SGD_model_test.predict(X_test[i])) 
    print (y_test[i])
# Out:
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['android']
# android
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['android']
# android
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['android']
# android
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['android']
# android
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['ios']
# ios
# >>>>>>>>>>>. ['android']
# android
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['corejava']
# corejava
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['android']
# android
# >>>>>>>>>>>. ['php']
# php
# >>>>>>>>>>>. ['pythondjango']
# pythondjango
# >>>>>>>>>>>. ['dotnet']
# dotnet
# >>>>>>>>>>>. ['php']
# php

# %%
svm_model_check = svm.SVC(kernel='linear') 
svm_model_check.fit(X_train, y_train) 
svm_prediction_check = svm_model_check.predict(X_test)
print ('svm_test:', np.mean(svm_prediction_check == y_test))
# Out:
# svm_test: 0.994444444444

# %%
SGD_model_check = SGDClassifier()
SGD_model_check.fit(X_train, y_train) 
SGD_prediction_check = SGD_model_check.predict(X_test)
print ('SGD_test:', np.mean(SGD_prediction_check == y_test))
# Out:
# SGD_test: 0.988888888889
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.ensemble import RandomForestClassifier  
RF_model_test = RandomForestClassifier(max_depth=2, random_state=0)
RF_model_test.fit(X_train, y_train) 
RF_prediction_test = RF_model_test.predict(X_test)
print ('RandomForest_test:', np.mean(RF_prediction_test == y_test))

from sklearn.tree import DecisionTreeClassifier
dtree_model_check = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train)
dtree_predictions_check = dtree_model_check.predict(X_test)
print ('DT_test:', np.mean(dtree_predictions_check == y_test))

from sklearn.neighbors import KNeighborsClassifier
knn_check = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
knn_predictions_check = knn_check.predict(X_test) 
print ('knn_test:', np.mean(knn_predictions_check == y_test))
# Out:
# RandomForest_test: 0.705555555556
# DT_test: 0.411111111111
# knn_test: 0.977777777778

# %%
target_names=['Resume', 'JobDescription']

# %%
y_pred = svm_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      1.00      1.00        28
# JobDescription       1.00      1.00      1.00        29
#
#    avg / total       0.99      0.99      0.99       180
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 6, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
y_pred = RF_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.64      0.25      0.36        28
# JobDescription       0.70      0.90      0.79        29
#
#    avg / total       0.73      0.71      0.69       180
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 6, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
y_pred = SGD_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      1.00      1.00        28
# JobDescription       1.00      1.00      1.00        29
#
#    avg / total       0.98      0.98      0.98       180
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 6, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
y_pred = dtree_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      0.96      0.98        28
# JobDescription       0.22      1.00      0.36        29
#
#    avg / total       0.30      0.41      0.31       180
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 6, does not match size of target_names, 2
#   .format(len(labels), len(target_names))
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       1.00      1.00      1.00        28
# JobDescription       0.94      1.00      0.97        29
#
#    avg / total       0.98      0.98      0.98       180
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 6, does not match size of target_names, 2
#   .format(len(labels), len(target_names))

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
SGD_model_test.predict(test_file)[0]
# Out:
# 'ios'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
svm_model.predict(test_file)[0]
# Out:
# 'ios'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])

RF_model.predict(test_file)[0]
# Out:
# 'ios'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
dtree_model.predict(test_file)[0]
# Out:
# 'ios'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
knn.predict(test_file)[0]
# Out:
# 'ios'
