# %%
import nltk, pickle, string
from nltk.corpus import stopwords
import re
import os
from tika import parser
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences


from textblob.classifiers import NaiveBayesClassifier as NBC
from textblob import TextBlob
# Out:
# Using TensorFlow backend.

# %%
def clean_doc(doc):
    """
    Cleaning a document by several methods:
        - Lowercase
        - Removing whitespaces
        - Removing stopwords
        - Removing punctuations
        
    """
    stop_words = set(stopwords.words('english'))
    
    # Lowercase
    doc = doc.lower()
   
    tokens = doc.translate({ord(c):"" for c in "\u200b\uf020\u2028\xa0\uf0e0\uf095\uf041\uf0e1\uf0b7\xad"})
    tokens = tokens.translate({ord(c):" " for c in "[):,·](;•●■♦▪"})
    tokens = tokens.translate({ord(c):"f" for c in "�"})
    
    # Removing multiple whitespaces
    tokens = re.sub(r"\?", " \? ", tokens)
    
    # Split in tokens
    tokens = tokens.split()
    
    # Remove Stopwords
    tokens = [w for w in tokens if not w in stop_words]
    # Remove punctuation
    tokens = [w.translate(str.maketrans('', '', string.punctuation)) for w in tokens]
    
    return ' '.join(tokens)

# %%
def LoadData_admin():
    label_admin=[]
    i=0
    for file in os.listdir("/home/shabna/Desktop/example_codes/new_sample/level4/tech/IT/administrator"):
        try:
            print (i, file)
            parsedPDF = parser.from_file("/home/shabna/Desktop/example_codes/new_sample/level4/tech/IT/administrator/"+file)

            tech_contents=clean_doc(parsedPDF['content'])
            #Data = resume_contents.encode('utf-8')    
            label_admin.append((tech_contents,'Administrator'))
        except UnicodeEncodeError:
            print ('Unicode error:', file)
        i=i+1
    #print (label_resume)
    return(label_admin)

# %%
def LoadData_others():
    label_others=[]
    i=1
    for file in os.listdir("/home/shabna/Desktop/example_codes/new_sample/level4/tech/IT/others"):
        try:
            print (i, file)
            parsedPDF = parser.from_file("/home/shabna/Desktop/example_codes/new_sample/level4/tech/IT/others/"+file)
        
            nontech_contents=clean_doc(parsedPDF['content'])
       
            
            label_others.append((nontech_contents, 'Others'))
        except UnicodeEncodeError:
            print ('Unicode error:', file)
        i=i+1
            
    return(label_others)

# %%
label_admin=LoadData_admin()
# Out:
# 0 Akshay_Chaudhary_Pune_10.06_yrs.doc
# 1 Gudlesh_Prajapati_Mumbai_2.10_yrs.doc
# 2 Binoj_P_Bengaluru___Bangalore_7.09_yrs.docx
# 3 BhanuPrakash S _ MSBI_Hyderabad_Atlas Systems.doc
# 4 Dhiraj_Sali_Pune_11.00_yrs.doc
# 5 Abhilash Rajan.doc
# 6 83604512_Chennai_12.00_yrs.doc
# 7 bejoy ks.pdf
# 8 Deepak_Resume 3i  (1).doc
# 9 Dhirendra_Kumar_Jha_Mumbai_14.03_yrs.doc
# 10 dilip_sakwadia_Pune_8.11_yrs.doc
# 11 Gangadhar_NG_Hyderabad___Secunderabad_5.00_yrs.docx
# 12 AKHIL_SABU_Kozhikode___Calicut_4.00_yrs.pdf
# 13 A.K.Murugesan_karuppusamy_Coimbatore_5.00_yrs.doc
# 14 Ajai_kumar_Bengaluru___Bangalore_6.10_yrs.doc
# 15 BinuJacobc .pdf
# 128 Free-Entry-Level-Network-Engineer-Resume-Free-Word.doc
# 129 BensonJonesProfile.pdf
# 130 Information Technology Consultant.doc
# 131 LOGANATHAN_K_Bengaluru___Bangalore_1.03_yrs.doc
# 132 SajadMohammadiKobarProfile.pdf
# 133 JeevithShettyProfile.pdf
# 134 Mandar_ovarikar__Pune_0.00_yrs.docx
# 135 AmirSatkinProfile.pdf
# 136 Network-Engineer-Resume-Sample-Doc.doc
# 137 SubinKumaranProfile.pdf
# 138 MasoudZeynaliProfile.pdf
# 139 MehdiTalebiProfile.pdf
# 140 Executive%20Hardware%20Engineer%20Resume%20Resume%20Templates%2003122018743408.pdf
# 141 Entry%20Level%20%26amp%3B%20Freshers%20Network%20Administrator%20Resume%20Resume%20Templates%2003122018683629.pdf
# 142 MohitTanwarProfile.pdf
# 143 Executive%20Network%20Administrator%20Resume%20Example%20Resume%20Templates%2003122018326897.pdf
# 144 80888692_Bengaluru___Bangalore_5.02_yrs.docx
# 145 ZaneMcCarreyProfile.pdf
# 146 FurqanAkhtarProfile.pdf
# 147 SrivatsaVasudevanProfile.pdf
# 148 Professional%20Network%20Technician%20Resume%20Resume%20Templates%2003122018271762.pdf
# 149 Harshad_Mahajan_Mumbai_2.07_yrs.doc
# 150 SoheilErshadiProfile.pdf

# %%
for row in label_others:
    data.append(row[0])
    data_labels.append(row[1])

# %%
print(len(data))
print(len(data_labels))
# Out:
# 300
# 300

# %%
print(len(data_labels))
# Out:
# 300

# %%
#labels = [0 for _ in range(len(label_resume))] + [1 for _ in range(len(label_jd))]
#print(labels)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=4, max_df=0.9)

# %%
# Apply model on jdres train data
train_vectors = vectorizer.fit_transform(data)
print(train_vectors)
# Out:
#   (0, 2345)	0.0339112044664
#   (0, 205)	0.0208520269158
#   (0, 1158)	0.0245017392855
#   (0, 1565)	0.0216836280072
#   (0, 3336)	0.0346100482137
#   (0, 3376)	0.0353755449282
#   (0, 623)	0.0175517093287
#   (0, 2173)	0.0159004109647
#   (0, 435)	0.0286859216543
#   (0, 2481)	0.0346100482137
#   (0, 2232)	0.0490158266742
#   (0, 2798)	0.0326731222471
#   (0, 3307)	0.021981130035
#   (0, 1778)	0.023369441142
#   (0, 2911)	0.0113551713097
#   (0, 231)	0.0371677528092
#   (0, 1805)	0.0273981077809
#   (0, 3258)	0.0346100482137
#   (0, 2280)	0.043077819843
#   (0, 3138)	0.050861021664
#   (0, 1126)	0.0371677528092
#   (0, 3468)	0.0566881966073
#   (0, 3221)	0.0280162308844
#   (0, 1472)	0.0181873115173
#   (0, 1408)	0.0371677528092
#   :	:
#   (299, 2606)	0.0651829452622
#   (299, 291)	0.0563198070284
#   (299, 118)	0.0511352035229
#   (299, 1550)	0.0539884967292
#   (299, 2074)	0.0913391200209
#   (299, 409)	0.0872385794366
#   (299, 2361)	0.0539884967292
#   (299, 162)	0.062851634963
#   (299, 1186)	0.0334089270554
#   (299, 249)	0.0551010942898
#   (299, 2935)	0.115334062915
#   (299, 3385)	0.104034803914
#   (299, 148)	0.0563198070284
#   (299, 2534)	0.0520174019568
#   (299, 3268)	0.0608805401906
#   (299, 3256)	0.0520174019568
#   (299, 2028)	0.062851634963
#   (299, 3334)	0.0651829452622
#   (299, 1575)	0.0520174019568
#   (299, 1230)	0.0651829452622
#   (299, 2238)	0.0651829452622
#   (299, 2865)	0.062851634963
#   (299, 1709)	0.0651829452622
#   (299, 1375)	0.062851634963
#   (299, 138)	0.0651829452622

# %%
X_train, X_test, y_train, y_test = train_test_split(train_vectors, data_labels, test_size=0.2, random_state=42)

# %%
svm_model = svm.SVC(kernel='linear') 
svm_model.fit(X_train, y_train) 
svm_prediction = svm_model.predict(X_train)
import numpy as np
print ('svm:', np.mean(svm_prediction == y_train))

'''for i in range(80):
    print ('>>>>>>>>>>>.',model.predict(train_vectors[i]))'''

    
from sklearn.ensemble import RandomForestClassifier  
RF_model = RandomForestClassifier(max_depth=2, random_state=0)
RF_model.fit(X_train, y_train) 
RF_prediction = RF_model.predict(X_train)
import numpy as np
print ('Random Forest:', np.mean(RF_prediction == y_train))

from sklearn.linear_model import SGDClassifier
SGD_model = SGDClassifier()
SGD_model.fit(X_train, y_train) 
SGD_prediction = SGD_model.predict(X_train)
import numpy as np
print ('SGD:', np.mean(SGD_prediction == y_train))

from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train,y_train)
dtree_predictions = dtree_model.predict(X_train)
print ('DT:', np.mean(dtree_predictions == y_train))


from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train,y_train)
knn_predictions = knn.predict(X_train) 
print ('knn:', np.mean(knn_predictions == y_train))
# Out:
# svm: 0.941666666667
# Random Forest: 0.904166666667
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGD: 0.975
# DT: 0.883333333333
# knn: 0.904166666667

# %%
for i in range(480):
    print ('>>>>>>>>>>>.',RF_model.predict(X_train[i]))
    print (y_train[i])
print(len(y_train))
# Out:
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-6a4cac722cf2> in <module>()
#       1 for i in range(480):
# ----> 2     print ('>>>>>>>>>>>.',RF_model.predict(X_train[i]))
#       3     print (y_train[i])
#       4 print(len(y_train))
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     290             # [i, 1:2]
#     291             elif isinstance(col, slice):
# --> 292                 return self._get_row_slice(row, col)
#     293             # [i, [1, 2]]
#     294             elif issequence(col):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_row_slice(self, i, cslice)
#     373
#     374         if i < 0 or i >= self.shape[0]:
# --> 375             raise IndexError('index (%d) out of range' % i)
#     376
#     377         start, stop, stride = cslice.indices(self.shape[1])
#
# IndexError: index (240) out of range

# %%
svm_model_test = svm.SVC(kernel='linear') 
svm_model_test.fit(X_test, y_test) 
svm_prediction_test = svm_model_test.predict(X_test)
print ('svm_test:', np.mean(svm_prediction_test == y_test))

# %%
from sklearn.ensemble import RandomForestClassifier  
RF_model_test = RandomForestClassifier(max_depth=2, random_state=0)
RF_model_test.fit(X_test, y_test) 
RF_prediction_test = RF_model_test.predict(X_test)
print ('RandomForest_test:', np.mean(RF_prediction_test == y_test))

# %%
from sklearn.linear_model import SGDClassifier
SGD_model_test = SGDClassifier()
SGD_model_test.fit(X_test, y_test) 
SGD_prediction_test = SGD_model_test.predict(X_test)
print ('SGD_test:', np.mean(SGD_prediction_test == y_test))
# Out:
# SGD_test: 1.0
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_model_test = DecisionTreeClassifier(max_depth = 2).fit(X_test, y_test)
dtree_predictions_test = dtree_model_test.predict(X_test)
print ('DT_test:', np.mean(dtree_predictions_test == y_test))

from sklearn.neighbors import KNeighborsClassifier
knn_test = KNeighborsClassifier(n_neighbors = 7).fit(X_test, y_test)
knn_predictions_test = knn_test.predict(X_test) 
print ('knn_test:', np.mean(knn_predictions_test == y_test))
# Out:
# DT_test: 0.95
# knn_test: 0.933333333333

# %%
"""for i in range(20):
    print ('>>>>>>>>>>>.',RF_model.predict(jdres_test_vectors[i]))
    print (jdres_test_labels[i])"""

for i in range(600):
    print ('>>>>>>>>>>>.',svm_model.predict(train_vectors[i]))
    print (data_labels[i])
# Out:
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-9e84401ec6b7> in <module>()
#       4
#       5 for i in range(600):
# ----> 6     print ('>>>>>>>>>>>.',svm_model.predict(train_vectors[i]))
#       7     print (data_labels[i])
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     290             # [i, 1:2]
#     291             elif isinstance(col, slice):
# --> 292                 return self._get_row_slice(row, col)
#     293             # [i, [1, 2]]
#     294             elif issequence(col):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_row_slice(self, i, cslice)
#     373
#     374         if i < 0 or i >= self.shape[0]:
# --> 375             raise IndexError('index (%d) out of range' % i)
#     376
#     377         start, stop, stride = cslice.indices(self.shape[1])
#
# IndexError: index (300) out of range

# %%
for i in range(120):
    print('>>>>>>>>>>>.',SGD_model_test.predict(X_test[i])) 
    print (y_test[i])
# Out:
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Administrator']
# Administrator
# >>>>>>>>>>>. ['Others']
# Others
# >>>>>>>>>>>. ['Administrator']
# Administrator
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-764f6dd60d6e> in <module>()
#       1 for i in range(120):
# ----> 2     print('>>>>>>>>>>>.',SGD_model_test.predict(X_test[i]))
#       3     print (y_test[i])
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     290             # [i, 1:2]
#     291             elif isinstance(col, slice):
# --> 292                 return self._get_row_slice(row, col)
#     293             # [i, [1, 2]]
#     294             elif issequence(col):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_row_slice(self, i, cslice)
#     373
#     374         if i < 0 or i >= self.shape[0]:
# --> 375             raise IndexError('index (%d) out of range' % i)
#     376
#     377         start, stop, stride = cslice.indices(self.shape[1])
#
# IndexError: index (60) out of range

# %%
svm_model_check = svm.SVC(kernel='linear') 
svm_model_check.fit(X_train, y_train) 
svm_prediction_check = svm_model_check.predict(X_test)
print ('svm_test:', np.mean(svm_prediction_check == y_test))
# Out:
# svm_test: 0.866666666667

# %%
SGD_model_check = SGDClassifier()
SGD_model_check.fit(X_train, y_train) 
SGD_prediction_check = SGD_model_check.predict(X_test)
print ('SGD_test:', np.mean(SGD_prediction_check == y_test))
# Out:
# SGD_test: 0.816666666667
# /home/shabna/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.ensemble import RandomForestClassifier  
RF_model_test = RandomForestClassifier(max_depth=2, random_state=0)
RF_model_test.fit(X_train, y_train) 
RF_prediction_test = RF_model_test.predict(X_test)
print ('RandomForest_test:', np.mean(RF_prediction_test == y_test))

from sklearn.tree import DecisionTreeClassifier
dtree_model_check = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train)
dtree_predictions_check = dtree_model_check.predict(X_test)
print ('DT_test:', np.mean(dtree_predictions_check == y_test))

from sklearn.neighbors import KNeighborsClassifier
knn_check = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
knn_predictions_check = knn_check.predict(X_test) 
print ('knn_test:', np.mean(knn_predictions_check == y_test))
# Out:
# RandomForest_test: 0.783333333333
# DT_test: 0.766666666667
# knn_test: 0.85

# %%
target_names=['Resume', 'JobDescription']

# %%
y_pred = svm_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.80      0.97      0.88        29
# JobDescription       0.96      0.77      0.86        31
#
#    avg / total       0.88      0.87      0.87        60

# %%
y_pred = RF_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.81      0.72      0.76        29
# JobDescription       0.76      0.84      0.80        31
#
#    avg / total       0.79      0.78      0.78        60

# %%
y_pred = SGD_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.77      0.79      0.78        29
# JobDescription       0.80      0.77      0.79        31
#
#    avg / total       0.78      0.78      0.78        60

# %%
y_pred = dtree_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.79      0.76      0.77        29
# JobDescription       0.78      0.81      0.79        31
#
#    avg / total       0.78      0.78      0.78        60

# %%
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#         Resume       0.79      0.93      0.86        29
# JobDescription       0.92      0.77      0.84        31
#
#    avg / total       0.86      0.85      0.85        60

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
SGD_model_test.predict(test_file)[0]
# Out:
# 'Others'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
svm_model.predict(test_file)[0]
# Out:
# 'Others'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])

RF_model.predict(test_file)[0]
# Out:
# 'Others'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
dtree_model.predict(test_file)[0]
# Out:
# 'Administrator'

# %%
test_file=vectorizer.transform(["/home/shabna/Desktop/example_codes/re/Resume/ios/48314531_India_2.09_yrs.pdf"])
knn.predict(test_file)[0]
# Out:
# 'Others'
